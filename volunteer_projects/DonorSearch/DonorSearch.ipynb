# %% [markdown]
# <a href="https://colab.research.google.com/github/kruspe2009/volunteer_projects/blob/main/volunteer_projects/DonorSearch/DonorSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Импорт библиотек и чтение данных

# %%
import pandas as pd

# %%
donations_anon = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DonorSearch/donations_anon.csv')
plan_anon = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DonorSearch/plan_anon.csv')
users_anon = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DonorSearch/users_anon.csv')

# %%
donations_anon.head()
# Out:
#       ID  ID пользователя  ... Статус донации Есть справка
# 0  97920           151894  ...   На модерации           Да
# 1  97919           156916  ...   На модерации           Да
# 2  97918           149413  ...        Принята           Да
# 3  97917           155027  ...        Принята           Да
# 4  97916           151094  ...        Принята           Да
#
# [5 rows x 10 columns]

# %%
plan_anon.head()
# Out:
#      ID  ID пользователя  ... Место стадчи           Есть справка
# 0  1413           141999  ...          711  донация запланирована
# 1  1412           158695  ...          660  донация запланирована
# 2  1411           156916  ...          633  донация запланирована
# 3  1410           156916  ...          633  планирование отменено
# 4  1409           158694  ...          765  донация запланирована
#
# [5 rows x 9 columns]

# %%
users_anon.head()
# Out:
#        ID         Пол  ... Дата регистрации Не подтверждённые донации
# 0  158697     Мужской  ...       02.06.2021                         0
# 1  158696     Мужской  ...       02.06.2021                         0
# 2  158695     Женский  ...       02.06.2021                         0
# 3  158694     Женский  ...       02.06.2021                         0
# 4  158690  Не указано  ...       02.06.2021                         0
#
# [5 rows x 21 columns]
